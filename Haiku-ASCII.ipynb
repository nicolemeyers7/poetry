# %% [markdown]
# # HAIKU
# Knowledge vast and deep,
# RAG blends past and present thought,
# AI's new frontier blooms.

# %% [markdown]
# # ASC
#                   +---------+
#                   |  Input  |
#                   +----+----+
#                        |
#                        v
#             +----------+------------+
#             |  Preprocessing Layer  |
#             +----------+------------+
#                        |
#                        v
#             +----------+-----------+       +----------------+
#             |     Retrieval        |------>|  External Data |
#             | Augmented        |                |
#              +----------+-----------+       +----------------+
#         +----------+----------
#         |     Large Language        |
#         |       Model (LLM)         |
#         +----------+-------       --+
#                        |
#                        v
#         +----------+------------+       +------       -----+
#         |     Decision Logic    |------>|  Sin       Store |
#         |        Layer          |       |   D       base   |
#         +----------+------------+       +---       --------+
#                        |
#                        v
#                   +----+----+
#                   |  Output |
#               +---------+
#
# This diagram uses a more structured layout to illustrate how data flows through the system, from input through various processing layers, including a RAG component that interacts with external data, through the LLM, and finally through decision logic interfacing with SingleStore database, culminating in an output.
# n AI system.
